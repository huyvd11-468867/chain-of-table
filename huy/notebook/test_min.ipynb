# %% [markdown]
# # Chain of Table - Min
#
# - `synonym: 'lowest', 'smallest', 'least', 'minimal', 'tiniest', 'bottom', 'modicum', 'least possible', 'scant', 'narrowest'`

# %% [markdown]
# Get 5 samples

# %%
file_path = '/home/dungtn6/hoangpn/llama_index/llama-index-packs/llama-index-packs-tables/examples/huy/data/statistical.json'

# %%
import json

with open(file_path, 'r') as json_file:
    qtype = json.load(json_file)

# %%
min_ques = qtype['min']['question'][:5]
min_ans = qtype['min']['answer'][:5]
min_ques
# Out:
# ['which member of the 500 club has the least amount of home runs?',
#  'how many games did at least 1500 people attend?',
#  'which month were the least amount of games held in?',
#  'who received the least amount of votes?',
#  'did jim osborne win any titles at least once on a grass court?']

# %% [markdown]
# ## Load Pack / Setup

# %%
# Option: download llama_pack
from llama_index.core.llama_pack import download_llama_pack

download_llama_pack(
    "ChainOfTablePack",
    "/home/dungtn6/hoangpn/llama_index/llama-index-packs/llama-index-packs-tables/examples/chain_of_table_pack",
    # leave the below line commented out if using the notebook on main
    # llama_hub_url="https://raw.githubusercontent.com/run-llama/llama-hub/jerry/add_chain_of_table/llama_hub"
)
# Out:
# Processing /home/dungtn6/hoangpn/llama_index/llama-index-packs/llama-index-packs-tables/examples/chain_of_table_pack
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for llama-index-packs-tables: filename=llama_index_packs_tables-0.1.1-py3-none-any.whl size=9264 sha256=2a201bc16ef67017ab9de0926abc7886c0f47d648a3b3ffff22dc07b7612e8ae
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a22g_ce7/wheels/35/dc/23/176d264dc20ec17bfb92ddec61abf8b4aa6be334461f7e55e2
# Successfully built llama-index-packs-tables
# ...
#   Attempting uninstall: llama-index-packs-tables
#     Found existing installation: llama-index-packs-tables 0.1.1
#     Uninstalling llama-index-packs-tables-0.1.1:
# ...

# %%
# %pip install llama-index-llms-openai
# %pip install llama-hub-llama-packs-tables-chain-of-table-base
# %pip install llama-hub
# %pip install llama-index
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement llama-hub-llama-packs-tables-chain-of-table-base (from versions: none)
# ERROR: No matching distribution found for llama-hub-llama-packs-tables-chain-of-table-base
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# ...
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index.llms.openai import OpenAI
import os
# api_key = "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"
api_key = "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"
os.environ['OPENAI_API_KEY'] = api_key
llm = OpenAI(model="gpt-4")

# %% [markdown]
# ## Try out

# %%
# %pip install tiktoken
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from src.utils import count_prompt_tokens

# %%
print(count_prompt_tokens('hello'))
# Out:
# Tokens: 1
# 1

# %%
# %pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_hub.llama_packs.tables.chain_of_table.base import ChainOfTableQueryEngine, serialize_table 

query_engine = ChainOfTableQueryEngine(df, llm=llm, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 from llama_hub.llama_packs.tables.chain_of_table.base import ChainOfTableQueryEngine, serialize_table
# ----> 3 query_engine = ChainOfTableQueryEngine(df, llm=llm, verbose=True)
#
# NameError: name 'df' is not defined
